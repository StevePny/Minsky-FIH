# %%
# Reproduction of Steve Keen's 2020 ROPE Emergent Macroeconomics result
# (Minsky model and figures 1 and 2)
#
# Stephen G. Penny
#
# Research Scientist
# Cooperative Institute for Research in Environmental Sciences (CIRES)
# at the University of Colorado Boulder
# 
# CEO and Founder
# S.E.A. Uprising, a public benefit company
# 
# 31 May, 2020

# %%
# Import the required modules
from class_minsky import minsky
# This makes the plots appear inside the notebook
# %matplotlib inline

import scipy as scipy
scipy.version.full_version
# Out:
# '1.1.0'

# %%
# Initialize minsky object and parameters
method = 'RK45' #'LSODA'
m0 = minsky(param_set='default') #alpha=0.015,beta=0.02,nu=3,delta_K=0.06,w_r=0.8,lamda_S=10,lamda_Z=0.6,pi_S=8,pi_Z=0.03,D=0,r=0.03)
m1 = minsky(param_set='figure1',method=method)
m2 = minsky(param_set='figure2',method=method)
# Out:
# default
# alpha   = 0.015
# beta    = 0.02
# nu      = 3.0
# delta_K = 0.06
# w_r     = 0.8
# lamda_S = 10.0
# lamda_Z = 0.6
# pi_S    = 8.0
# pi_Z    = 0.03
# D       = 0
# r       = 0.03
# method  = RK45
# x0      = [0.62, 0.9, 0]
# t0 = 0, tf = 100, dt = 0.01
#
# figure1
# alpha   = 0.02
# beta    = 0.015
# nu      = 3.0
# delta_K = 0.06
# w_r     = 0.8
# lamda_S = 4.0
# lamda_Z = 0.6
# pi_S    = 4.6
# pi_Z    = 0.03
# D       = 0
# r       = 0.04
# method  = LSODA
# x0      = [0.61, 0.85, 0.0]
# t0 = 0, tf = 400, dt = 0.1
#
# figure2
# alpha   = 0.02
# beta    = 0.015
# nu      = 3.0
# delta_K = 0.06
# w_r     = 0.8
# lamda_S = 4.0
# lamda_Z = 0.6
# pi_S    = 10.0
# pi_Z    = 0.03
# D       = 0
# r       = 0.04
# method  = LSODA
# x0      = [0.61, 0.85, 0.0]
# t0 = 0, tf = 100, dt = 0.01

# %%
# Run the model
m0.run()
m1.run()
m2.run()
# Out:
# run:: t0 = 0, tf = 100, dt = 0.01
# run:: t0 = 0, tf = 400, dt = 0.1
# run:: t0 = 0, tf = 100, dt = 0.01

# %%
# Plot model output with default parameters (from Table 1)
m0.plot_figure()

# %%
# Plot figure 1
m1.plot_figure()

# %%
# Plot figure 2
m2.plot_figure()
